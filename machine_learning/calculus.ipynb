# %%
import sympy

# %%
J, a = sympy.symbols('J,a')

# %%
import math
J = (1/2)*(a-5)**2
J
# Out:
# 0.5*(a - 5)**2

# %%
dj_da=sympy.diff(J,a)
dj_da
# Out:
# 1.0*a - 5.0

# %%
dj_da.subs([(a,7)])
# Out:
# 2.00000000000000
